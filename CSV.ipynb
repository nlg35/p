# %% [markdown]
# # Documentation bibliothèque tables

# %% [markdown]
# Cette bibliothèque permet de lire et manipuler les données d'un fichier csv.

# %% [markdown]
# ## 1) définition de types de variables plus compréhensibles

# %%
Attribut = str
Valeur = str
Ligne = Dict[Attribut, Valeur]
Table = List[Ligne]

# %% [markdown]
# Une table est une liste de ligne.
# Une ligne est un dictionnaire d'attributs/Valeurs
#
# donc une table est une liste de dictionnaire d'attributs/Valeurs
#
# Table = List[{'A1': 'V1a', 'A2': 'V2a'},{'A1': 'V1b', 'A2': 'V2b'}]

# %% [markdown]
# ## 2) Créer un dictionnaire de listes à partir du fichier

# %% [markdown]
# Utilisation :

# %%
import csv 

def depuis_csv(nom_fichier_csv):
    """
        Crée une liste de dictionnaires, un par ligne.
        La 1Łre ligne du fichier csv est considérée comme la ligne des noms des champs
    """
    lecteur = csv.DictReader(open(nom_fichier_csv,'r'))
    return [dict(ligne) for ligne in lecteur]

dico =depuis_csv('monument_nationaux.csv')

# %% [markdown]
# retourne :

# %%
[{'Attribut1': 'Valeur1a', 'Attribut2': 'Valeur2a'}, 
{'Attribut1': 'Valeur1b', 'Attribut2': 'Valeur2b'}, 
{'Attribut1': 'Valeur1c', 'Attribut2': 'Valeur2c'}]

# %% [markdown]
# Exemple : Afficher le dictionnaire (dico)

# %%
dico
# Out:
# [{'monument_nom': 'Abbaye de Beaulieu-en-Rouergue',
#   'monument_lat': '44.2012986000000',
#   'monument_lon': '1.8576953000000',
#   'Frequentation': '8819'},
#  {'monument_nom': 'Abbaye de Charroux',
#   'monument_lat': '46.1417360000000',
#   'monument_lon': '0.4049650000000',
#   'Frequentation': '1883'},
#  {'monument_nom': 'Abbaye de Cluny',
#   'monument_lat': '46.4351729231305',
#   'monument_lon': '4.6582192182541',
#   'Frequentation': '124110'},
#  {'monument_nom': 'Abbaye de La Sauve-Majeure',
#   'monument_lat': '44.7679000000000',
#   'monument_lon': '-0.3125000000000',
#   'Frequentation': '13390'},
#  {'monument_nom': 'Abbaye de Montmajour',
#   'monument_lat': '43.7056788063795',
#   'monument_lon': '4.6641482412815',
#   'Frequentation': '40234'},
#  {'monument_nom': 'Abbaye du Bec-Hellouin',
#   'monument_lat': '49.2286110000000',
#   'monument_lon': '0.7216670000000',
#   'Frequentation': '7243'},
#  {'monument_nom': 'Abbaye du Mont-Saint-Michel',
#   'monument_lat': '48.6359715815921',
#   'monument_lon': '-1.5114140510559',
#   'Frequentation': '1270506'},
#  {'monument_nom': 'Abbaye du Thoronet',
#   'monument_lat': '43.4501102000000',
#   'monument_lon': '6.3080895000000',
#   'Frequentation': '107935'},
#  {'monument_nom': 'Alignements de Carnac',
#   'monument_lat': '47.5977020000000',
#   'monument_lon': '-3.0633934000000',
#   'Frequentation': '23567'},
#  {'monument_nom': 'Arc de triomphe',
#   'monument_lat': '48.8738180000000',
#   'monument_lon': '2.2950230000000',
#   'Frequentation': '1732280'},
#  {'monument_nom': 'Basilique cathédrale de Saint-Denis',
#   'monument_lat': '48.9354196846302',
#   'monument_lon': '2.3599147796631',
#   'Frequentation': '171441'},
#  {'monument_nom': 'Cairn de Barnenez',
#   'monument_lat': '48.6675691351204',
#   'monument_lon': '-3.8584274053574',
#   'Frequentation': '32499'},
#  {'monument_nom': 'Cathédrale de Besançon et son horloge astronomique',
#   'monument_lat': '47.2336343000000',
#   'monument_lon': '6.0303255000000',
#   'Frequentation': '7445'},
#  {'monument_nom': 'Chapelle expiatoire',
#   'monument_lat': '48.8736985969585',
#   'monument_lon': '2.3226910829544',
#   'Frequentation': '6021'},
#  {'monument_nom': "Château d'Angers",
#   'monument_lat': '47.4698136000000',
#   'monument_lon': '-0.5593384000000',
#   'Frequentation': '166533'},
#  {'monument_nom': "Château d'Assier",
#   'monument_lat': '44.6752839000000',
#   'monument_lon': '1.8792255000000',
#   'Frequentation': '3948'},
#  {'monument_nom': "Château d'Aulteribe",
#   'monument_lat': '45.7750000000000',
#   'monument_lon': '3.4988890000000',
#   'Frequentation': '6693'},
#  {'monument_nom': "Château d'Azay-le-Rideau",
#   'monument_lat': '47.2595533000000',
#   'monument_lon': '0.4666037000000',
#   'Frequentation': '293594'},
#  {'monument_nom': "Château d'If",
#   'monument_lat': '43.2798571264442',
#   'monument_lon': '5.3251343965530',
#   'Frequentation': '90584'},
#  {'monument_nom': "Château d'Oiron",
#   'monument_lat': '46.9518734665508',
#   'monument_lon': '-0.0773334503174',
#   'Frequentation': '20035'},
#  {'monument_nom': 'Château de Bouges',
#   'monument_lat': '47.0424048078576',
#   'monument_lon': '1.6729688644409',
#   'Frequentation': '11608'},
#  {'monument_nom': 'Château de Bussy-Rabutin',
#   'monument_lat': '47.5615776782153',
#   'monument_lon': '4.5234757661820',
#   'Frequentation': '31940'},
#  {'monument_nom': 'Château de Cadillac',
#   'monument_lat': '44.6381012193490',
#   'monument_lon': '-0.3206527233124',
#   'Frequentation': '11071'},
#  {'monument_nom': 'Château de Carrouges',
#   'monument_lat': '48.5601290798993',
#   'monument_lon': '-0.1543450355530',
#   'Frequentation': '22907'},
#  {'monument_nom': 'Château de Castelnau-Bretenoux',
#   'monument_lat': '44.8992000000000',
#   'monument_lon': '1.8256000000000',
#   'Frequentation': '47494'},
#  {'monument_nom': 'Château de Chareil-Cintrat',
#   'monument_lat': '46.2394201556751',
#   'monument_lon': '3.2297229766846',
#   'Frequentation': '2018'},
#  {'monument_nom': 'Château de Châteaudun',
#   'monument_lat': '48.0707956173737',
#   'monument_lon': '1.3237237930298',
#   'Frequentation': '20615'},
#  {'monument_nom': 'Château de Coucy',
#   'monument_lat': '49.5217748552510',
#   'monument_lon': '3.3186113834381',
#   'Frequentation': '14528'},
#  {'monument_nom': 'Château de Fougères-sur-Bièvre',
#   'monument_lat': '47.4477388488549',
#   'monument_lon': '1.3438081741333',
#   'Frequentation': '17227'},
#  {'monument_nom': 'Château de Gramont',
#   'monument_lat': '43.9580329000000',
#   'monument_lon': '0.9211763000000',
#   'Frequentation': '4681'},
#  {'monument_nom': 'Château de La Motte-Tilly',
#   'monument_lat': '48.4671345668952',
#   'monument_lon': '3.4314733743668',
#   'Frequentation': '4111'},
#  {'monument_nom': 'Château de Montal',
#   'monument_lat': '44.8624197000000',
#   'monument_lon': '1.8599192000000',
#   'Frequentation': '17713'},
#  {'monument_nom': 'Château de Pierrefonds',
#   'monument_lat': '49.3469937613645',
#   'monument_lon': '2.9801970720291',
#   'Frequentation': '134568'},
#  {'monument_nom': 'Château de Puyguilhem',
#   'monument_lat': '45.4258330000000',
#   'monument_lon': '0.7444440000000',
#   'Frequentation': '15361'},
#  {'monument_nom': 'Château de Rambouillet et Laiterie de la Reine et Chaumière aux Coquillages',
#   'monument_lat': '48.6454040146198',
#   'monument_lon': '1.8173280358315',
#   'Frequentation': '28418'},
#  {'monument_nom': 'Château de Talcy',
#   'monument_lat': '47.7697553616761',
#   'monument_lon': '1.4444768428803',
#   'Frequentation': '13453'},
#  {'monument_nom': 'Château de Villeneuve-Lembron',
#   'monument_lat': '45.4779965450436',
#   'monument_lon': '3.1859707832336',
#   'Frequentation': '6975'},
#  {'monument_nom': 'Château de Vincennes',
#   'monument_lat': '48.8426682454500',
#   'monument_lon': '2.4357032775879',
#   'Frequentation': '139155'},
#  {'monument_nom': 'Château de Voltaire à Ferney',
#   'monument_lat': '46.2581309000000',
#   'monument_lon': '6.1043544000000',
#   'Frequentation': '10536'},
#  {'monument_nom': 'Château et remparts de la cité de Carcassonne',
#   'monument_lat': '43.2072833574495',
#   'monument_lon': '2.3632621765137',
#   'Frequentation': '471707'},
#  {'monument_nom': 'Cloître de la cathédrale de Fréjus',
#   'monument_lat': '43.4330627773556',
#   'monument_lon': '6.7371511459351',
#   'Frequentation': '25865'},
#  {'monument_nom': 'Cloître de la cathédrale du Puy-en-Velay',
#   'monument_lat': '45.0461801000000',
#   'monument_lon': '3.8848592000000',
#   'Frequentation': '24783'},
#  {'monument_nom': 'Cloître de la Psalette à Tours',
#   'monument_lat': '47.3958291154544',
#   'monument_lon': '0.6940698623657',
#   'Frequentation': '17804'},
#  {'monument_nom': 'Colonne de la Grande Armée à Wimille',
#   'monument_lat': '50.7644118000000',
#   'monument_lon': '1.6310642000000',
#   'Frequentation': '4881'},
#  {'monument_nom': 'Conciergerie',
#   'monument_lat': '48.8558175524787',
#   'monument_lon': '2.3459511995316',
#   'Frequentation': '456589'},
#  {'monument_nom': 'Domaine national de Saint-Cloud',
#   'monument_lat': '48.8368214312740',
#   'monument_lon': '2.2182083129883',
#   'Frequentation': '141019'},
#  {'monument_nom': 'Fort Saint-André à Villeneuve-lez-Avignon',
#   'monument_lat': '43.9662000000000',
#   'monument_lon': '4.8001000000000',
#   'Frequentation': '29068'},
#  {'monument_nom': 'Forteresse de Salses',
#   'monument_lat': '42.8396802790619',
#   'monument_lon': '2.9183024168015',
#   'Frequentation': '77951'},
#  {'monument_nom': 'Grotte de Pair-non-Pair',
#   'monument_lat': '45.0396354000000',
#   'monument_lon': '-0.5022214000000',
#   'Frequentation': '11316'},
#  {'monument_nom': "Maison d'Ernest Renan à Tréguier",
#   'monument_lat': '48.7884910000000',
#   'monument_lon': '-3.2271867000000',
#   'Frequentation': '33077'},
#  {'monument_nom': 'Maison de George Sand à Nohant',
#   'monument_lat': '46.6254445000000',
#   'monument_lon': '1.9749036000000',
#   'Frequentation': '16639'},
#  {'monument_nom': 'Maison de Georges Clemenceau à Saint-Vincent-sur-Jard',
#   'monument_lat': '46.4063000000000',
#   'monument_lon': '-1.5474000000000',
#   'Frequentation': '2743'},
#  {'monument_nom': 'Maison des Jardies à Sèvres',
#   'monument_lat': '48.8272072000000',
#   'monument_lon': '2.1985906000000',
#   'Frequentation': '867'},
#  {'monument_nom': 'Monastère de Saorge',
#   'monument_lat': '43.9878757000000',
#   'monument_lon': '7.5509564000000',
#   'Frequentation': '7374'},
#  {'monument_nom': 'Monastère royal de Brou à Bourg-en-Bresse',
#   'monument_lat': '46.1978767000000',
#   'monument_lon': '5.2356066000000',
#   'Frequentation': '57627'},
#  {'monument_nom': 'Palais du Tau à Reims',
#   'monument_lat': '49.2530901204998',
#   'monument_lon': '4.0341818332672',
#   'Frequentation': '62623'},
#  {'monument_nom': 'Palais Jacques Coeur à Bourges',
#   'monument_lat': '47.0852960000000',
#   'monument_lon': '2.3944818000000',
#   'Frequentation': '47464'},
#  {'monument_nom': 'Panthéon',
#   'monument_lat': '48.8462842078404',
#   'monument_lon': '2.3460732400417',
#   'Frequentation': '724392'},
#  {'monument_nom': 'Place forte de Mont-Dauphin',
#   'monument_lat': '44.6691299000000',
#   'monument_lon': '6.6252286000000',
#   'Frequentation': '10652'},
#  {'monument_nom': 'Sainte-Chapelle',
#   'monument_lat': '48.8553675326006',
#   'monument_lon': '2.3450231552124',
#   'Frequentation': '951807'},
#  {'monument_nom': 'Site archéologique de Glanum',
#   'monument_lat': '43.7736000000000',
#   'monument_lon': '4.8330000000000',
#   'Frequentation': '73795'},
#  {'monument_nom': 'Site archéologique de Montcaret',
#   'monument_lat': '44.8587327000000',
#   'monument_lon': '0.0638404000000',
#   'Frequentation': '7651'},
#  {'monument_nom': "Site archéologique et musée d'Ensérune",
#   'monument_lat': '43.3105560000000',
#   'monument_lon': '3.1152780000000',
#   'Frequentation': '30095'},
#  {'monument_nom': 'Site des mégalithes de Locmariaquer',
#   'monument_lat': '47.5732972000000',
#   'monument_lon': '-2.9574633000000',
#   'Frequentation': '56656'},
#  {'monument_nom': 'Site gallo-romain de Sanxay',
#   'monument_lat': '46.4941324000000',
#   'monument_lon': '-0.0070385000000',
#   'Frequentation': '6243'},
#  {'monument_nom': 'Tour et crypte de la cathédrale de Bourges',
#   'monument_lat': '47.0824115207644',
#   'monument_lon': '2.3984956741333',
#   'Frequentation': '33506'},
#  {'monument_nom': 'Tour Pey-Berland à Bordeaux',
#   'monument_lat': '44.8379962000000',
#   'monument_lon': '-0.5777064000000',
#   'Frequentation': '51685'},
#  {'monument_nom': "Tours de la cathédrale d'Amiens",
#   'monument_lat': '49.8950000000000',
#   'monument_lon': '2.3022220000000',
#   'Frequentation': '8819'},
#  {'monument_nom': 'Tours de la cathédrale de Chartres',
#   'monument_lat': '48.4477636872284',
#   'monument_lon': '1.4879822731018',
#   'Frequentation': '26055'},
#  {'monument_nom': 'Tours de la cathédrale de Reims',
#   'monument_lat': '49.2534000000000',
#   'monument_lon': '4.0330000000000',
#   'Frequentation': '11439'},
#  {'monument_nom': 'Tours de la cathédrale Notre-Dame de Paris',
#   'monument_lat': '48.8529761826414',
#   'monument_lon': '2.3499530553818',
#   'Frequentation': '494283'},
#  {'monument_nom': 'Tours de La Rochelle',
#   'monument_lat': '46.1558010144313',
#   'monument_lon': '-1.1532318592072',
#   'Frequentation': '119033'},
#  {'monument_nom': "Tours et remparts d'Aigues-Mortes",
#   'monument_lat': '43.5678143607364',
#   'monument_lon': '4.1908657550812',
#   'Frequentation': '167051'},
#  {'monument_nom': "Trophée d'Auguste à La Turbie",
#   'monument_lat': '43.7448050133043',
#   'monument_lon': '7.4018400907517',
#   'Frequentation': '18595'},
#  {'monument_nom': 'Villa Savoye à Poissy',
#   'monument_lat': '48.9244255560091',
#   'monument_lon': '2.0282703638077',
#   'Frequentation': '32884'}]

# %% [markdown]
# ## 3) Selection

# %% [markdown]
# Une sélection est une instruction permettant de sélectionner un ensemble de lignes dans une table respectant un critère.

# %% [markdown]
# Utilisation :

# %%
from typing import List,  Dict

Ligne = Dict[Attribut, Valeur]
Table = List[Ligne]

def select(table: Table, critère: str) -> Table:
    def test(ligne: Ligne) -> bool:
        return eval(critère)
    return [ligne for ligne in table if test(ligne)]

# %% [markdown]
# Exemple :

# %%
frequentation =select(dico,"'Monastère' in ligne['monument_nom']")
frequentation
# Out:
# [{'monument_nom': 'Monastère de Saorge',
#   'monument_lat': '43.9878757000000',
#   'monument_lon': '7.5509564000000',
#   'Frequentation': '7374'},
#  {'monument_nom': 'Monastère royal de Brou à Bourg-en-Bresse',
#   'monument_lat': '46.1978767000000',
#   'monument_lon': '5.2356066000000',
#   'Frequentation': '57627'}]

# %% [markdown]
# Autres exemples de critères :

# %%
    "'Fort' in ligne['monument_nom'] or 'Fort' in ligne['monument_nom']" 
    "'5000' < ligne['Frequentation']"

# %% [markdown]
# ### 4) Projection

# %% [markdown]
# Une projection est une instruction permettant de sélectionner un ensemble de colonnes dans une table.

# %% [markdown]
# Utilisation :

# %%
def projection(table:Table, liste_cles:List[Attribut]) -> Table:
    return [{cle:ligne[cle] for cle in ligne if cle in liste_cles} for ligne in table]

# %% [markdown]
# Exemple :Afficher la table qui contient les noms des monuments

# %%
projection(dico, ['monument_nom'])
# Out:
# [{'monument_nom': 'Abbaye de Beaulieu-en-Rouergue'},
#  {'monument_nom': 'Abbaye de Charroux'},
#  {'monument_nom': 'Abbaye de Cluny'},
#  {'monument_nom': 'Abbaye de La Sauve-Majeure'},
#  {'monument_nom': 'Abbaye de Montmajour'},
#  {'monument_nom': 'Abbaye du Bec-Hellouin'},
#  {'monument_nom': 'Abbaye du Mont-Saint-Michel'},
#  {'monument_nom': 'Abbaye du Thoronet'},
#  {'monument_nom': 'Alignements de Carnac'},
#  {'monument_nom': 'Arc de triomphe'},
#  {'monument_nom': 'Basilique cathédrale de Saint-Denis'},
#  {'monument_nom': 'Cairn de Barnenez'},
#  {'monument_nom': 'Cathédrale de Besançon et son horloge astronomique'},
#  {'monument_nom': 'Chapelle expiatoire'},
#  {'monument_nom': "Château d'Angers"},
#  {'monument_nom': "Château d'Assier"},
#  {'monument_nom': "Château d'Aulteribe"},
#  {'monument_nom': "Château d'Azay-le-Rideau"},
#  {'monument_nom': "Château d'If"},
#  {'monument_nom': "Château d'Oiron"},
#  {'monument_nom': 'Château de Bouges'},
#  {'monument_nom': 'Château de Bussy-Rabutin'},
#  {'monument_nom': 'Château de Cadillac'},
#  {'monument_nom': 'Château de Carrouges'},
#  {'monument_nom': 'Château de Castelnau-Bretenoux'},
#  {'monument_nom': 'Château de Chareil-Cintrat'},
#  {'monument_nom': 'Château de Châteaudun'},
#  {'monument_nom': 'Château de Coucy'},
#  {'monument_nom': 'Château de Fougères-sur-Bièvre'},
#  {'monument_nom': 'Château de Gramont'},
#  {'monument_nom': 'Château de La Motte-Tilly'},
#  {'monument_nom': 'Château de Montal'},
#  {'monument_nom': 'Château de Pierrefonds'},
#  {'monument_nom': 'Château de Puyguilhem'},
#  {'monument_nom': 'Château de Rambouillet et Laiterie de la Reine et Chaumière aux Coquillages'},
#  {'monument_nom': 'Château de Talcy'},
#  {'monument_nom': 'Château de Villeneuve-Lembron'},
#  {'monument_nom': 'Château de Vincennes'},
#  {'monument_nom': 'Château de Voltaire à Ferney'},
#  {'monument_nom': 'Château et remparts de la cité de Carcassonne'},
#  {'monument_nom': 'Cloître de la cathédrale de Fréjus'},
#  {'monument_nom': 'Cloître de la cathédrale du Puy-en-Velay'},
#  {'monument_nom': 'Cloître de la Psalette à Tours'},
#  {'monument_nom': 'Colonne de la Grande Armée à Wimille'},
#  {'monument_nom': 'Conciergerie'},
#  {'monument_nom': 'Domaine national de Saint-Cloud'},
#  {'monument_nom': 'Fort Saint-André à Villeneuve-lez-Avignon'},
#  {'monument_nom': 'Forteresse de Salses'},
#  {'monument_nom': 'Grotte de Pair-non-Pair'},
#  {'monument_nom': "Maison d'Ernest Renan à Tréguier"},
#  {'monument_nom': 'Maison de George Sand à Nohant'},
#  {'monument_nom': 'Maison de Georges Clemenceau à Saint-Vincent-sur-Jard'},
#  {'monument_nom': 'Maison des Jardies à Sèvres'},
#  {'monument_nom': 'Monastère de Saorge'},
#  {'monument_nom': 'Monastère royal de Brou à Bourg-en-Bresse'},
#  {'monument_nom': 'Palais du Tau à Reims'},
#  {'monument_nom': 'Palais Jacques Coeur à Bourges'},
#  {'monument_nom': 'Panthéon'},
#  {'monument_nom': 'Place forte de Mont-Dauphin'},
#  {'monument_nom': 'Sainte-Chapelle'},
#  {'monument_nom': 'Site archéologique de Glanum'},
#  {'monument_nom': 'Site archéologique de Montcaret'},
#  {'monument_nom': "Site archéologique et musée d'Ensérune"},
#  {'monument_nom': 'Site des mégalithes de Locmariaquer'},
#  {'monument_nom': 'Site gallo-romain de Sanxay'},
#  {'monument_nom': 'Tour et crypte de la cathédrale de Bourges'},
#  {'monument_nom': 'Tour Pey-Berland à Bordeaux'},
#  {'monument_nom': "Tours de la cathédrale d'Amiens"},
#  {'monument_nom': 'Tours de la cathédrale de Chartres'},
#  {'monument_nom': 'Tours de la cathédrale de Reims'},
#  {'monument_nom': 'Tours de la cathédrale Notre-Dame de Paris'},
#  {'monument_nom': 'Tours de La Rochelle'},
#  {'monument_nom': "Tours et remparts d'Aigues-Mortes"},
#  {'monument_nom': "Trophée d'Auguste à La Turbie"},
#  {'monument_nom': 'Villa Savoye à Poissy'}]

# %% [markdown]
# ### 5) Tri

# %% [markdown]
# Un tri est une instruction permettant de trier les lignes d'une table selon un attribut (ou colonne) dans un ordre (croissant oudécroissant).

# %%
def tri_numerique(table: Table, attribut: Attribut, decroit:bool =False) -> Table:
    def critère_numerique(ligne: Ligne):
        return float(ligne[attribut])
    return sorted(table, key=critère_numerique, reverse=decroit)

# %%
def tri(table: Table, attribut: Attribut, decroit:bool =False) -> Table:
    def critère(ligne: Ligne):
        return ligne[attribut]
    return sorted(table, key=critère, reverse=decroit)

# %% [markdown]
# Exemple : Trier les monuments par fréquentation

# %%
tri_numerique(dico, 'Frequentation')
# Out:
# [{'monument_nom': 'Maison des Jardies à Sèvres',
#   'monument_lat': '48.8272072000000',
#   'monument_lon': '2.1985906000000',
#   'Frequentation': '867'},
#  {'monument_nom': 'Abbaye de Charroux',
#   'monument_lat': '46.1417360000000',
#   'monument_lon': '0.4049650000000',
#   'Frequentation': '1883'},
#  {'monument_nom': 'Château de Chareil-Cintrat',
#   'monument_lat': '46.2394201556751',
#   'monument_lon': '3.2297229766846',
#   'Frequentation': '2018'},
#  {'monument_nom': 'Maison de Georges Clemenceau à Saint-Vincent-sur-Jard',
#   'monument_lat': '46.4063000000000',
#   'monument_lon': '-1.5474000000000',
#   'Frequentation': '2743'},
#  {'monument_nom': "Château d'Assier",
#   'monument_lat': '44.6752839000000',
#   'monument_lon': '1.8792255000000',
#   'Frequentation': '3948'},
#  {'monument_nom': 'Château de La Motte-Tilly',
#   'monument_lat': '48.4671345668952',
#   'monument_lon': '3.4314733743668',
#   'Frequentation': '4111'},
#  {'monument_nom': 'Château de Gramont',
#   'monument_lat': '43.9580329000000',
#   'monument_lon': '0.9211763000000',
#   'Frequentation': '4681'},
#  {'monument_nom': 'Colonne de la Grande Armée à Wimille',
#   'monument_lat': '50.7644118000000',
#   'monument_lon': '1.6310642000000',
#   'Frequentation': '4881'},
#  {'monument_nom': 'Chapelle expiatoire',
#   'monument_lat': '48.8736985969585',
#   'monument_lon': '2.3226910829544',
#   'Frequentation': '6021'},
#  {'monument_nom': 'Site gallo-romain de Sanxay',
#   'monument_lat': '46.4941324000000',
#   'monument_lon': '-0.0070385000000',
#   'Frequentation': '6243'},
#  {'monument_nom': "Château d'Aulteribe",
#   'monument_lat': '45.7750000000000',
#   'monument_lon': '3.4988890000000',
#   'Frequentation': '6693'},
#  {'monument_nom': 'Château de Villeneuve-Lembron',
#   'monument_lat': '45.4779965450436',
#   'monument_lon': '3.1859707832336',
#   'Frequentation': '6975'},
#  {'monument_nom': 'Abbaye du Bec-Hellouin',
#   'monument_lat': '49.2286110000000',
#   'monument_lon': '0.7216670000000',
#   'Frequentation': '7243'},
#  {'monument_nom': 'Monastère de Saorge',
#   'monument_lat': '43.9878757000000',
#   'monument_lon': '7.5509564000000',
#   'Frequentation': '7374'},
#  {'monument_nom': 'Cathédrale de Besançon et son horloge astronomique',
#   'monument_lat': '47.2336343000000',
#   'monument_lon': '6.0303255000000',
#   'Frequentation': '7445'},
#  {'monument_nom': 'Site archéologique de Montcaret',
#   'monument_lat': '44.8587327000000',
#   'monument_lon': '0.0638404000000',
#   'Frequentation': '7651'},
#  {'monument_nom': 'Abbaye de Beaulieu-en-Rouergue',
#   'monument_lat': '44.2012986000000',
#   'monument_lon': '1.8576953000000',
#   'Frequentation': '8819'},
#  {'monument_nom': "Tours de la cathédrale d'Amiens",
#   'monument_lat': '49.8950000000000',
#   'monument_lon': '2.3022220000000',
#   'Frequentation': '8819'},
#  {'monument_nom': 'Château de Voltaire à Ferney',
#   'monument_lat': '46.2581309000000',
#   'monument_lon': '6.1043544000000',
#   'Frequentation': '10536'},
#  {'monument_nom': 'Place forte de Mont-Dauphin',
#   'monument_lat': '44.6691299000000',
#   'monument_lon': '6.6252286000000',
#   'Frequentation': '10652'},
#  {'monument_nom': 'Château de Cadillac',
#   'monument_lat': '44.6381012193490',
#   'monument_lon': '-0.3206527233124',
#   'Frequentation': '11071'},
#  {'monument_nom': 'Grotte de Pair-non-Pair',
#   'monument_lat': '45.0396354000000',
#   'monument_lon': '-0.5022214000000',
#   'Frequentation': '11316'},
#  {'monument_nom': 'Tours de la cathédrale de Reims',
#   'monument_lat': '49.2534000000000',
#   'monument_lon': '4.0330000000000',
#   'Frequentation': '11439'},
#  {'monument_nom': 'Château de Bouges',
#   'monument_lat': '47.0424048078576',
#   'monument_lon': '1.6729688644409',
#   'Frequentation': '11608'},
#  {'monument_nom': 'Abbaye de La Sauve-Majeure',
#   'monument_lat': '44.7679000000000',
#   'monument_lon': '-0.3125000000000',
#   'Frequentation': '13390'},
#  {'monument_nom': 'Château de Talcy',
#   'monument_lat': '47.7697553616761',
#   'monument_lon': '1.4444768428803',
#   'Frequentation': '13453'},
#  {'monument_nom': 'Château de Coucy',
#   'monument_lat': '49.5217748552510',
#   'monument_lon': '3.3186113834381',
#   'Frequentation': '14528'},
#  {'monument_nom': 'Château de Puyguilhem',
#   'monument_lat': '45.4258330000000',
#   'monument_lon': '0.7444440000000',
#   'Frequentation': '15361'},
#  {'monument_nom': 'Maison de George Sand à Nohant',
#   'monument_lat': '46.6254445000000',
#   'monument_lon': '1.9749036000000',
#   'Frequentation': '16639'},
#  {'monument_nom': 'Château de Fougères-sur-Bièvre',
#   'monument_lat': '47.4477388488549',
#   'monument_lon': '1.3438081741333',
#   'Frequentation': '17227'},
#  {'monument_nom': 'Château de Montal',
#   'monument_lat': '44.8624197000000',
#   'monument_lon': '1.8599192000000',
#   'Frequentation': '17713'},
#  {'monument_nom': 'Cloître de la Psalette à Tours',
#   'monument_lat': '47.3958291154544',
#   'monument_lon': '0.6940698623657',
#   'Frequentation': '17804'},
#  {'monument_nom': "Trophée d'Auguste à La Turbie",
#   'monument_lat': '43.7448050133043',
#   'monument_lon': '7.4018400907517',
#   'Frequentation': '18595'},
#  {'monument_nom': "Château d'Oiron",
#   'monument_lat': '46.9518734665508',
#   'monument_lon': '-0.0773334503174',
#   'Frequentation': '20035'},
#  {'monument_nom': 'Château de Châteaudun',
#   'monument_lat': '48.0707956173737',
#   'monument_lon': '1.3237237930298',
#   'Frequentation': '20615'},
#  {'monument_nom': 'Château de Carrouges',
#   'monument_lat': '48.5601290798993',
#   'monument_lon': '-0.1543450355530',
#   'Frequentation': '22907'},
#  {'monument_nom': 'Alignements de Carnac',
#   'monument_lat': '47.5977020000000',
#   'monument_lon': '-3.0633934000000',
#   'Frequentation': '23567'},
#  {'monument_nom': 'Cloître de la cathédrale du Puy-en-Velay',
#   'monument_lat': '45.0461801000000',
#   'monument_lon': '3.8848592000000',
#   'Frequentation': '24783'},
#  {'monument_nom': 'Cloître de la cathédrale de Fréjus',
#   'monument_lat': '43.4330627773556',
#   'monument_lon': '6.7371511459351',
#   'Frequentation': '25865'},
#  {'monument_nom': 'Tours de la cathédrale de Chartres',
#   'monument_lat': '48.4477636872284',
#   'monument_lon': '1.4879822731018',
#   'Frequentation': '26055'},
#  {'monument_nom': 'Château de Rambouillet et Laiterie de la Reine et Chaumière aux Coquillages',
#   'monument_lat': '48.6454040146198',
#   'monument_lon': '1.8173280358315',
#   'Frequentation': '28418'},
#  {'monument_nom': 'Fort Saint-André à Villeneuve-lez-Avignon',
#   'monument_lat': '43.9662000000000',
#   'monument_lon': '4.8001000000000',
#   'Frequentation': '29068'},
#  {'monument_nom': "Site archéologique et musée d'Ensérune",
#   'monument_lat': '43.3105560000000',
#   'monument_lon': '3.1152780000000',
#   'Frequentation': '30095'},
#  {'monument_nom': 'Château de Bussy-Rabutin',
#   'monument_lat': '47.5615776782153',
#   'monument_lon': '4.5234757661820',
#   'Frequentation': '31940'},
#  {'monument_nom': 'Cairn de Barnenez',
#   'monument_lat': '48.6675691351204',
#   'monument_lon': '-3.8584274053574',
#   'Frequentation': '32499'},
#  {'monument_nom': 'Villa Savoye à Poissy',
#   'monument_lat': '48.9244255560091',
#   'monument_lon': '2.0282703638077',
#   'Frequentation': '32884'},
#  {'monument_nom': "Maison d'Ernest Renan à Tréguier",
#   'monument_lat': '48.7884910000000',
#   'monument_lon': '-3.2271867000000',
#   'Frequentation': '33077'},
#  {'monument_nom': 'Tour et crypte de la cathédrale de Bourges',
#   'monument_lat': '47.0824115207644',
#   'monument_lon': '2.3984956741333',
#   'Frequentation': '33506'},
#  {'monument_nom': 'Abbaye de Montmajour',
#   'monument_lat': '43.7056788063795',
#   'monument_lon': '4.6641482412815',
#   'Frequentation': '40234'},
#  {'monument_nom': 'Palais Jacques Coeur à Bourges',
#   'monument_lat': '47.0852960000000',
#   'monument_lon': '2.3944818000000',
#   'Frequentation': '47464'},
#  {'monument_nom': 'Château de Castelnau-Bretenoux',
#   'monument_lat': '44.8992000000000',
#   'monument_lon': '1.8256000000000',
#   'Frequentation': '47494'},
#  {'monument_nom': 'Tour Pey-Berland à Bordeaux',
#   'monument_lat': '44.8379962000000',
#   'monument_lon': '-0.5777064000000',
#   'Frequentation': '51685'},
#  {'monument_nom': 'Site des mégalithes de Locmariaquer',
#   'monument_lat': '47.5732972000000',
#   'monument_lon': '-2.9574633000000',
#   'Frequentation': '56656'},
#  {'monument_nom': 'Monastère royal de Brou à Bourg-en-Bresse',
#   'monument_lat': '46.1978767000000',
#   'monument_lon': '5.2356066000000',
#   'Frequentation': '57627'},
#  {'monument_nom': 'Palais du Tau à Reims',
#   'monument_lat': '49.2530901204998',
#   'monument_lon': '4.0341818332672',
#   'Frequentation': '62623'},
#  {'monument_nom': 'Site archéologique de Glanum',
#   'monument_lat': '43.7736000000000',
#   'monument_lon': '4.8330000000000',
#   'Frequentation': '73795'},
#  {'monument_nom': 'Forteresse de Salses',
#   'monument_lat': '42.8396802790619',
#   'monument_lon': '2.9183024168015',
#   'Frequentation': '77951'},
#  {'monument_nom': "Château d'If",
#   'monument_lat': '43.2798571264442',
#   'monument_lon': '5.3251343965530',
#   'Frequentation': '90584'},
#  {'monument_nom': 'Abbaye du Thoronet',
#   'monument_lat': '43.4501102000000',
#   'monument_lon': '6.3080895000000',
#   'Frequentation': '107935'},
#  {'monument_nom': 'Tours de La Rochelle',
#   'monument_lat': '46.1558010144313',
#   'monument_lon': '-1.1532318592072',
#   'Frequentation': '119033'},
#  {'monument_nom': 'Abbaye de Cluny',
#   'monument_lat': '46.4351729231305',
#   'monument_lon': '4.6582192182541',
#   'Frequentation': '124110'},
#  {'monument_nom': 'Château de Pierrefonds',
#   'monument_lat': '49.3469937613645',
#   'monument_lon': '2.9801970720291',
#   'Frequentation': '134568'},
#  {'monument_nom': 'Château de Vincennes',
#   'monument_lat': '48.8426682454500',
#   'monument_lon': '2.4357032775879',
#   'Frequentation': '139155'},
#  {'monument_nom': 'Domaine national de Saint-Cloud',
#   'monument_lat': '48.8368214312740',
#   'monument_lon': '2.2182083129883',
#   'Frequentation': '141019'},
#  {'monument_nom': "Château d'Angers",
#   'monument_lat': '47.4698136000000',
#   'monument_lon': '-0.5593384000000',
#   'Frequentation': '166533'},
#  {'monument_nom': "Tours et remparts d'Aigues-Mortes",
#   'monument_lat': '43.5678143607364',
#   'monument_lon': '4.1908657550812',
#   'Frequentation': '167051'},
#  {'monument_nom': 'Basilique cathédrale de Saint-Denis',
#   'monument_lat': '48.9354196846302',
#   'monument_lon': '2.3599147796631',
#   'Frequentation': '171441'},
#  {'monument_nom': "Château d'Azay-le-Rideau",
#   'monument_lat': '47.2595533000000',
#   'monument_lon': '0.4666037000000',
#   'Frequentation': '293594'},
#  {'monument_nom': 'Conciergerie',
#   'monument_lat': '48.8558175524787',
#   'monument_lon': '2.3459511995316',
#   'Frequentation': '456589'},
#  {'monument_nom': 'Château et remparts de la cité de Carcassonne',
#   'monument_lat': '43.2072833574495',
#   'monument_lon': '2.3632621765137',
#   'Frequentation': '471707'},
#  {'monument_nom': 'Tours de la cathédrale Notre-Dame de Paris',
#   'monument_lat': '48.8529761826414',
#   'monument_lon': '2.3499530553818',
#   'Frequentation': '494283'},
#  {'monument_nom': 'Panthéon',
#   'monument_lat': '48.8462842078404',
#   'monument_lon': '2.3460732400417',
#   'Frequentation': '724392'},
#  {'monument_nom': 'Sainte-Chapelle',
#   'monument_lat': '48.8553675326006',
#   'monument_lon': '2.3450231552124',
#   'Frequentation': '951807'},
#  {'monument_nom': 'Abbaye du Mont-Saint-Michel',
#   'monument_lat': '48.6359715815921',
#   'monument_lon': '-1.5114140510559',
#   'Frequentation': '1270506'},
#  {'monument_nom': 'Arc de triomphe',
#   'monument_lat': '48.8738180000000',
#   'monument_lon': '2.2950230000000',
#   'Frequentation': '1732280'}]

# %% [markdown]
# Exemple : Tri des noms dans l'ordre alphabétique

# %%
tri(dico, 'monument_nom')
# Out:
# [{'monument_nom': 'Abbaye de Beaulieu-en-Rouergue',
#   'monument_lat': '44.2012986000000',
#   'monument_lon': '1.8576953000000',
#   'Frequentation': '8819'},
#  {'monument_nom': 'Abbaye de Charroux',
#   'monument_lat': '46.1417360000000',
#   'monument_lon': '0.4049650000000',
#   'Frequentation': '1883'},
#  {'monument_nom': 'Abbaye de Cluny',
#   'monument_lat': '46.4351729231305',
#   'monument_lon': '4.6582192182541',
#   'Frequentation': '124110'},
#  {'monument_nom': 'Abbaye de La Sauve-Majeure',
#   'monument_lat': '44.7679000000000',
#   'monument_lon': '-0.3125000000000',
#   'Frequentation': '13390'},
#  {'monument_nom': 'Abbaye de Montmajour',
#   'monument_lat': '43.7056788063795',
#   'monument_lon': '4.6641482412815',
#   'Frequentation': '40234'},
#  {'monument_nom': 'Abbaye du Bec-Hellouin',
#   'monument_lat': '49.2286110000000',
#   'monument_lon': '0.7216670000000',
#   'Frequentation': '7243'},
#  {'monument_nom': 'Abbaye du Mont-Saint-Michel',
#   'monument_lat': '48.6359715815921',
#   'monument_lon': '-1.5114140510559',
#   'Frequentation': '1270506'},
#  {'monument_nom': 'Abbaye du Thoronet',
#   'monument_lat': '43.4501102000000',
#   'monument_lon': '6.3080895000000',
#   'Frequentation': '107935'},
#  {'monument_nom': 'Alignements de Carnac',
#   'monument_lat': '47.5977020000000',
#   'monument_lon': '-3.0633934000000',
#   'Frequentation': '23567'},
#  {'monument_nom': 'Arc de triomphe',
#   'monument_lat': '48.8738180000000',
#   'monument_lon': '2.2950230000000',
#   'Frequentation': '1732280'},
#  {'monument_nom': 'Basilique cathédrale de Saint-Denis',
#   'monument_lat': '48.9354196846302',
#   'monument_lon': '2.3599147796631',
#   'Frequentation': '171441'},
#  {'monument_nom': 'Cairn de Barnenez',
#   'monument_lat': '48.6675691351204',
#   'monument_lon': '-3.8584274053574',
#   'Frequentation': '32499'},
#  {'monument_nom': 'Cathédrale de Besançon et son horloge astronomique',
#   'monument_lat': '47.2336343000000',
#   'monument_lon': '6.0303255000000',
#   'Frequentation': '7445'},
#  {'monument_nom': 'Chapelle expiatoire',
#   'monument_lat': '48.8736985969585',
#   'monument_lon': '2.3226910829544',
#   'Frequentation': '6021'},
#  {'monument_nom': "Château d'Angers",
#   'monument_lat': '47.4698136000000',
#   'monument_lon': '-0.5593384000000',
#   'Frequentation': '166533'},
#  {'monument_nom': "Château d'Assier",
#   'monument_lat': '44.6752839000000',
#   'monument_lon': '1.8792255000000',
#   'Frequentation': '3948'},
#  {'monument_nom': "Château d'Aulteribe",
#   'monument_lat': '45.7750000000000',
#   'monument_lon': '3.4988890000000',
#   'Frequentation': '6693'},
#  {'monument_nom': "Château d'Azay-le-Rideau",
#   'monument_lat': '47.2595533000000',
#   'monument_lon': '0.4666037000000',
#   'Frequentation': '293594'},
#  {'monument_nom': "Château d'If",
#   'monument_lat': '43.2798571264442',
#   'monument_lon': '5.3251343965530',
#   'Frequentation': '90584'},
#  {'monument_nom': "Château d'Oiron",
#   'monument_lat': '46.9518734665508',
#   'monument_lon': '-0.0773334503174',
#   'Frequentation': '20035'},
#  {'monument_nom': 'Château de Bouges',
#   'monument_lat': '47.0424048078576',
#   'monument_lon': '1.6729688644409',
#   'Frequentation': '11608'},
#  {'monument_nom': 'Château de Bussy-Rabutin',
#   'monument_lat': '47.5615776782153',
#   'monument_lon': '4.5234757661820',
#   'Frequentation': '31940'},
#  {'monument_nom': 'Château de Cadillac',
#   'monument_lat': '44.6381012193490',
#   'monument_lon': '-0.3206527233124',
#   'Frequentation': '11071'},
#  {'monument_nom': 'Château de Carrouges',
#   'monument_lat': '48.5601290798993',
#   'monument_lon': '-0.1543450355530',
#   'Frequentation': '22907'},
#  {'monument_nom': 'Château de Castelnau-Bretenoux',
#   'monument_lat': '44.8992000000000',
#   'monument_lon': '1.8256000000000',
#   'Frequentation': '47494'},
#  {'monument_nom': 'Château de Chareil-Cintrat',
#   'monument_lat': '46.2394201556751',
#   'monument_lon': '3.2297229766846',
#   'Frequentation': '2018'},
#  {'monument_nom': 'Château de Châteaudun',
#   'monument_lat': '48.0707956173737',
#   'monument_lon': '1.3237237930298',
#   'Frequentation': '20615'},
#  {'monument_nom': 'Château de Coucy',
#   'monument_lat': '49.5217748552510',
#   'monument_lon': '3.3186113834381',
#   'Frequentation': '14528'},
#  {'monument_nom': 'Château de Fougères-sur-Bièvre',
#   'monument_lat': '47.4477388488549',
#   'monument_lon': '1.3438081741333',
#   'Frequentation': '17227'},
#  {'monument_nom': 'Château de Gramont',
#   'monument_lat': '43.9580329000000',
#   'monument_lon': '0.9211763000000',
#   'Frequentation': '4681'},
#  {'monument_nom': 'Château de La Motte-Tilly',
#   'monument_lat': '48.4671345668952',
#   'monument_lon': '3.4314733743668',
#   'Frequentation': '4111'},
#  {'monument_nom': 'Château de Montal',
#   'monument_lat': '44.8624197000000',
#   'monument_lon': '1.8599192000000',
#   'Frequentation': '17713'},
#  {'monument_nom': 'Château de Pierrefonds',
#   'monument_lat': '49.3469937613645',
#   'monument_lon': '2.9801970720291',
#   'Frequentation': '134568'},
#  {'monument_nom': 'Château de Puyguilhem',
#   'monument_lat': '45.4258330000000',
#   'monument_lon': '0.7444440000000',
#   'Frequentation': '15361'},
#  {'monument_nom': 'Château de Rambouillet et Laiterie de la Reine et Chaumière aux Coquillages',
#   'monument_lat': '48.6454040146198',
#   'monument_lon': '1.8173280358315',
#   'Frequentation': '28418'},
#  {'monument_nom': 'Château de Talcy',
#   'monument_lat': '47.7697553616761',
#   'monument_lon': '1.4444768428803',
#   'Frequentation': '13453'},
#  {'monument_nom': 'Château de Villeneuve-Lembron',
#   'monument_lat': '45.4779965450436',
#   'monument_lon': '3.1859707832336',
#   'Frequentation': '6975'},
#  {'monument_nom': 'Château de Vincennes',
#   'monument_lat': '48.8426682454500',
#   'monument_lon': '2.4357032775879',
#   'Frequentation': '139155'},
#  {'monument_nom': 'Château de Voltaire à Ferney',
#   'monument_lat': '46.2581309000000',
#   'monument_lon': '6.1043544000000',
#   'Frequentation': '10536'},
#  {'monument_nom': 'Château et remparts de la cité de Carcassonne',
#   'monument_lat': '43.2072833574495',
#   'monument_lon': '2.3632621765137',
#   'Frequentation': '471707'},
#  {'monument_nom': 'Cloître de la Psalette à Tours',
#   'monument_lat': '47.3958291154544',
#   'monument_lon': '0.6940698623657',
#   'Frequentation': '17804'},
#  {'monument_nom': 'Cloître de la cathédrale de Fréjus',
#   'monument_lat': '43.4330627773556',
#   'monument_lon': '6.7371511459351',
#   'Frequentation': '25865'},
#  {'monument_nom': 'Cloître de la cathédrale du Puy-en-Velay',
#   'monument_lat': '45.0461801000000',
#   'monument_lon': '3.8848592000000',
#   'Frequentation': '24783'},
#  {'monument_nom': 'Colonne de la Grande Armée à Wimille',
#   'monument_lat': '50.7644118000000',
#   'monument_lon': '1.6310642000000',
#   'Frequentation': '4881'},
#  {'monument_nom': 'Conciergerie',
#   'monument_lat': '48.8558175524787',
#   'monument_lon': '2.3459511995316',
#   'Frequentation': '456589'},
#  {'monument_nom': 'Domaine national de Saint-Cloud',
#   'monument_lat': '48.8368214312740',
#   'monument_lon': '2.2182083129883',
#   'Frequentation': '141019'},
#  {'monument_nom': 'Fort Saint-André à Villeneuve-lez-Avignon',
#   'monument_lat': '43.9662000000000',
#   'monument_lon': '4.8001000000000',
#   'Frequentation': '29068'},
#  {'monument_nom': 'Forteresse de Salses',
#   'monument_lat': '42.8396802790619',
#   'monument_lon': '2.9183024168015',
#   'Frequentation': '77951'},
#  {'monument_nom': 'Grotte de Pair-non-Pair',
#   'monument_lat': '45.0396354000000',
#   'monument_lon': '-0.5022214000000',
#   'Frequentation': '11316'},
#  {'monument_nom': "Maison d'Ernest Renan à Tréguier",
#   'monument_lat': '48.7884910000000',
#   'monument_lon': '-3.2271867000000',
#   'Frequentation': '33077'},
#  {'monument_nom': 'Maison de George Sand à Nohant',
#   'monument_lat': '46.6254445000000',
#   'monument_lon': '1.9749036000000',
#   'Frequentation': '16639'},
#  {'monument_nom': 'Maison de Georges Clemenceau à Saint-Vincent-sur-Jard',
#   'monument_lat': '46.4063000000000',
#   'monument_lon': '-1.5474000000000',
#   'Frequentation': '2743'},
#  {'monument_nom': 'Maison des Jardies à Sèvres',
#   'monument_lat': '48.8272072000000',
#   'monument_lon': '2.1985906000000',
#   'Frequentation': '867'},
#  {'monument_nom': 'Monastère de Saorge',
#   'monument_lat': '43.9878757000000',
#   'monument_lon': '7.5509564000000',
#   'Frequentation': '7374'},
#  {'monument_nom': 'Monastère royal de Brou à Bourg-en-Bresse',
#   'monument_lat': '46.1978767000000',
#   'monument_lon': '5.2356066000000',
#   'Frequentation': '57627'},
#  {'monument_nom': 'Palais Jacques Coeur à Bourges',
#   'monument_lat': '47.0852960000000',
#   'monument_lon': '2.3944818000000',
#   'Frequentation': '47464'},
#  {'monument_nom': 'Palais du Tau à Reims',
#   'monument_lat': '49.2530901204998',
#   'monument_lon': '4.0341818332672',
#   'Frequentation': '62623'},
#  {'monument_nom': 'Panthéon',
#   'monument_lat': '48.8462842078404',
#   'monument_lon': '2.3460732400417',
#   'Frequentation': '724392'},
#  {'monument_nom': 'Place forte de Mont-Dauphin',
#   'monument_lat': '44.6691299000000',
#   'monument_lon': '6.6252286000000',
#   'Frequentation': '10652'},
#  {'monument_nom': 'Sainte-Chapelle',
#   'monument_lat': '48.8553675326006',
#   'monument_lon': '2.3450231552124',
#   'Frequentation': '951807'},
#  {'monument_nom': 'Site archéologique de Glanum',
#   'monument_lat': '43.7736000000000',
#   'monument_lon': '4.8330000000000',
#   'Frequentation': '73795'},
#  {'monument_nom': 'Site archéologique de Montcaret',
#   'monument_lat': '44.8587327000000',
#   'monument_lon': '0.0638404000000',
#   'Frequentation': '7651'},
#  {'monument_nom': "Site archéologique et musée d'Ensérune",
#   'monument_lat': '43.3105560000000',
#   'monument_lon': '3.1152780000000',
#   'Frequentation': '30095'},
#  {'monument_nom': 'Site des mégalithes de Locmariaquer',
#   'monument_lat': '47.5732972000000',
#   'monument_lon': '-2.9574633000000',
#   'Frequentation': '56656'},
#  {'monument_nom': 'Site gallo-romain de Sanxay',
#   'monument_lat': '46.4941324000000',
#   'monument_lon': '-0.0070385000000',
#   'Frequentation': '6243'},
#  {'monument_nom': 'Tour Pey-Berland à Bordeaux',
#   'monument_lat': '44.8379962000000',
#   'monument_lon': '-0.5777064000000',
#   'Frequentation': '51685'},
#  {'monument_nom': 'Tour et crypte de la cathédrale de Bourges',
#   'monument_lat': '47.0824115207644',
#   'monument_lon': '2.3984956741333',
#   'Frequentation': '33506'},
#  {'monument_nom': 'Tours de La Rochelle',
#   'monument_lat': '46.1558010144313',
#   'monument_lon': '-1.1532318592072',
#   'Frequentation': '119033'},
#  {'monument_nom': 'Tours de la cathédrale Notre-Dame de Paris',
#   'monument_lat': '48.8529761826414',
#   'monument_lon': '2.3499530553818',
#   'Frequentation': '494283'},
#  {'monument_nom': "Tours de la cathédrale d'Amiens",
#   'monument_lat': '49.8950000000000',
#   'monument_lon': '2.3022220000000',
#   'Frequentation': '8819'},
#  {'monument_nom': 'Tours de la cathédrale de Chartres',
#   'monument_lat': '48.4477636872284',
#   'monument_lon': '1.4879822731018',
#   'Frequentation': '26055'},
#  {'monument_nom': 'Tours de la cathédrale de Reims',
#   'monument_lat': '49.2534000000000',
#   'monument_lon': '4.0330000000000',
#   'Frequentation': '11439'},
#  {'monument_nom': "Tours et remparts d'Aigues-Mortes",
#   'monument_lat': '43.5678143607364',
#   'monument_lon': '4.1908657550812',
#   'Frequentation': '167051'},
#  {'monument_nom': "Trophée d'Auguste à La Turbie",
#   'monument_lat': '43.7448050133043',
#   'monument_lon': '7.4018400907517',
#   'Frequentation': '18595'},
#  {'monument_nom': 'Villa Savoye à Poissy',
#   'monument_lat': '48.9244255560091',
#   'monument_lon': '2.0282703638077',
#   'Frequentation': '32884'}]

# %% [markdown]
# ### 6) Union de deux tables

# %%
from copy import deepcopy

def union(table1: Table, table2: Table, cle1: Attribut, cle2: Attribut = None) -> Table:
    if cle2 is None: # Par défaut les clés de jointure portent le même nom
        cle2 = cle1
    new_table: Table = []  # La future table créée, vide au départ
    for ligne1 in table1: 
        for ligne2 in table2:
		    #  on ne  considère que  les lignes  où les  cellules de  l'attribut
		    # choisi sont identiques. 
            if ligne1[cle1] == ligne2[cle2]:
                new_line = deepcopy(ligne1) # on copie entièrement la ligne de table1 
                for cle in ligne2: # on copie la ligne de table2 sans répéter la
                                   # cellule de jointure
                    if cle != cle2:
                        new_line[cle] = ligne2[cle]
                new_table.append(new_line)
    return new_table

# %%
table_freq=depuis_csv('monuments_frequentation.csv')
table_freq
# Out:
# [{'monument_id': '1',
#   'monument_nom': 'Abbaye de Beaulieu-en-Rouergue',
#   'Frequentation': '8819'},
#  {'monument_id': '2',
#   'monument_nom': 'Abbaye de Charroux',
#   'Frequentation': '1883'},
#  {'monument_id': '3',
#   'monument_nom': 'Abbaye de Cluny',
#   'Frequentation': '124110'},
#  {'monument_id': '4',
#   'monument_nom': 'Abbaye de La Sauve-Majeure',
#   'Frequentation': '13390'},
#  {'monument_id': '5',
#   'monument_nom': 'Abbaye de Montmajour',
#   'Frequentation': '40234'},
#  {'monument_id': '6',
#   'monument_nom': 'Abbaye du Bec-Hellouin',
#   'Frequentation': '7243'},
#  {'monument_id': '7',
#   'monument_nom': 'Abbaye du Mont-Saint-Michel',
#   'Frequentation': '1270506'},
#  {'monument_id': '8',
#   'monument_nom': 'Abbaye du Thoronet',
#   'Frequentation': '107935'},
#  {'monument_id': '9',
#   'monument_nom': 'Alignements de Carnac',
#   'Frequentation': '23567'},
#  {'monument_id': '10',
#   'monument_nom': 'Arc de triomphe',
#   'Frequentation': '1732280'},
#  {'monument_id': '11',
#   'monument_nom': 'Basilique cathÃ©drale de Saint-Denis',
#   'Frequentation': '171441'},
#  {'monument_id': '12',
#   'monument_nom': 'Cairn de Barnenez',
#   'Frequentation': '32499'},
#  {'monument_id': '13',
#   'monument_nom': 'CathÃ©drale de BesanÃ§on et son horloge astronomique',
#   'Frequentation': '7445'},
#  {'monument_id': '14',
#   'monument_nom': 'Chapelle expiatoire',
#   'Frequentation': '6021'},
#  {'monument_id': '15',
#   'monument_nom': "ChÃ¢teau d'Angers",
#   'Frequentation': '166533'},
#  {'monument_id': '16',
#   'monument_nom': "ChÃ¢teau d'Assier",
#   'Frequentation': '3948'},
#  {'monument_id': '17',
#   'monument_nom': "ChÃ¢teau d'Aulteribe",
#   'Frequentation': '6693'},
#  {'monument_id': '18',
#   'monument_nom': "ChÃ¢teau d'Azay-le-Rideau",
#   'Frequentation': '293594'},
#  {'monument_id': '19',
#   'monument_nom': "ChÃ¢teau d'If",
#   'Frequentation': '90584'},
#  {'monument_id': '20',
#   'monument_nom': "ChÃ¢teau d'Oiron",
#   'Frequentation': '20035'},
#  {'monument_id': '21',
#   'monument_nom': 'ChÃ¢teau de Bouges',
#   'Frequentation': '11608'},
#  {'monument_id': '22',
#   'monument_nom': 'ChÃ¢teau de Bussy-Rabutin',
#   'Frequentation': '31940'},
#  {'monument_id': '23',
#   'monument_nom': 'ChÃ¢teau de Cadillac',
#   'Frequentation': '11071'},
#  {'monument_id': '24',
#   'monument_nom': 'ChÃ¢teau de Carrouges',
#   'Frequentation': '22907'},
#  {'monument_id': '25',
#   'monument_nom': 'ChÃ¢teau de Castelnau-Bretenoux',
#   'Frequentation': '47494'},
#  {'monument_id': '26',
#   'monument_nom': 'ChÃ¢teau de Chareil-Cintrat',
#   'Frequentation': '2018'},
#  {'monument_id': '27',
#   'monument_nom': 'ChÃ¢teau de ChÃ¢teaudun',
#   'Frequentation': '20615'},
#  {'monument_id': '28',
#   'monument_nom': 'ChÃ¢teau de Coucy',
#   'Frequentation': '14528'},
#  {'monument_id': '29',
#   'monument_nom': 'ChÃ¢teau de FougÃ¨res-sur-BiÃ¨vre',
#   'Frequentation': '17227'},
#  {'monument_id': '30',
#   'monument_nom': 'ChÃ¢teau de Gramont',
#   'Frequentation': '4681'},
#  {'monument_id': '31',
#   'monument_nom': 'ChÃ¢teau de La Motte-Tilly',
#   'Frequentation': '4111'},
#  {'monument_id': '32',
#   'monument_nom': 'ChÃ¢teau de Montal',
#   'Frequentation': '17713'},
#  {'monument_id': '33',
#   'monument_nom': 'ChÃ¢teau de Pierrefonds',
#   'Frequentation': '134568'},
#  {'monument_id': '34',
#   'monument_nom': 'ChÃ¢teau de Puyguilhem',
#   'Frequentation': '15361'},
#  {'monument_id': '35',
#   'monument_nom': 'ChÃ¢teau de Rambouillet et Laiterie de la Reine et ChaumiÃ¨re aux Coquillages',
#   'Frequentation': '28418'},
#  {'monument_id': '36',
#   'monument_nom': 'ChÃ¢teau de Talcy',
#   'Frequentation': '13453'},
#  {'monument_id': '37',
#   'monument_nom': 'ChÃ¢teau de Villeneuve-Lembron',
#   'Frequentation': '6975'},
#  {'monument_id': '38',
#   'monument_nom': 'ChÃ¢teau de Vincennes',
#   'Frequentation': '139155'},
#  {'monument_id': '39',
#   'monument_nom': 'ChÃ¢teau de Voltaire Ã\xa0 Ferney',
#   'Frequentation': '10536'},
#  {'monument_id': '40',
#   'monument_nom': 'ChÃ¢teau et remparts de la citÃ© de Carcassonne',
#   'Frequentation': '471707'},
#  {'monument_id': '41',
#   'monument_nom': 'CloÃ®tre de la cathÃ©drale de FrÃ©jus',
#   'Frequentation': '25865'},
#  {'monument_id': '42',
#   'monument_nom': 'CloÃ®tre de la cathÃ©drale du Puy-en-Velay',
#   'Frequentation': '24783'},
#  {'monument_id': '43',
#   'monument_nom': 'CloÃ®tre de la Psalette Ã\xa0 Tours',
#   'Frequentation': '17804'},
#  {'monument_id': '44',
#   'monument_nom': 'Colonne de la Grande ArmÃ©e Ã\xa0 Wimille',
#   'Frequentation': '4881'},
#  {'monument_id': '45',
#   'monument_nom': 'Conciergerie',
#   'Frequentation': '456589'},
#  {'monument_id': '46',
#   'monument_nom': 'Domaine national de Saint-Cloud',
#   'Frequentation': '141019'},
#  {'monument_id': '47',
#   'monument_nom': 'Fort Saint-AndrÃ© Ã\xa0 Villeneuve-lez-Avignon',
#   'Frequentation': '29068'},
#  {'monument_id': '48',
#   'monument_nom': 'Forteresse de Salses',
#   'Frequentation': '77951'},
#  {'monument_id': '49',
#   'monument_nom': 'Grotte de Pair-non-Pair',
#   'Frequentation': '11316'},
#  {'monument_id': '50',
#   'monument_nom': "Maison d'Ernest Renan Ã\xa0 TrÃ©guier",
#   'Frequentation': '33077'},
#  {'monument_id': '51',
#   'monument_nom': 'Maison de George Sand Ã\xa0 Nohant',
#   'Frequentation': '16639'},
#  {'monument_id': '52',
#   'monument_nom': 'Maison de Georges Clemenceau Ã\xa0 Saint-Vincent-sur-Jard',
#   'Frequentation': '2743'},
#  {'monument_id': '53',
#   'monument_nom': 'Maison des Jardies Ã\xa0 SÃ¨vres',
#   'Frequentation': '867'},
#  {'monument_id': '54',
#   'monument_nom': 'MonastÃ¨re de Saorge',
#   'Frequentation': '7374'},
#  {'monument_id': '55',
#   'monument_nom': 'MonastÃ¨re royal de Brou Ã\xa0 Bourg-en-Bresse',
#   'Frequentation': '57627'},
#  {'monument_id': '56',
#   'monument_nom': 'Palais du Tau Ã\xa0 Reims',
#   'Frequentation': '62623'},
#  {'monument_id': '57',
#   'monument_nom': 'Palais Jacques Coeur Ã\xa0 Bourges',
#   'Frequentation': '47464'},
#  {'monument_id': '58', 'monument_nom': 'PanthÃ©on', 'Frequentation': '724392'},
#  {'monument_id': '59',
#   'monument_nom': 'Place forte de Mont-Dauphin',
#   'Frequentation': '10652'},
#  {'monument_id': '60',
#   'monument_nom': 'Sainte-Chapelle',
#   'Frequentation': '951807'},
#  {'monument_id': '61',
#   'monument_nom': 'Site archÃ©ologique de Glanum',
#   'Frequentation': '73795'},
#  {'monument_id': '62',
#   'monument_nom': 'Site archÃ©ologique de Montcaret',
#   'Frequentation': '7651'},
#  {'monument_id': '63',
#   'monument_nom': "Site archÃ©ologique et musÃ©e d'EnsÃ©rune",
#   'Frequentation': '30095'},
#  {'monument_id': '64',
#   'monument_nom': 'Site des mÃ©galithes de Locmariaquer',
#   'Frequentation': '56656'},
#  {'monument_id': '65',
#   'monument_nom': 'Site gallo-romain de Sanxay',
#   'Frequentation': '6243'},
#  {'monument_id': '66',
#   'monument_nom': 'Tour et crypte de la cathÃ©drale de Bourges',
#   'Frequentation': '33506'},
#  {'monument_id': '67',
#   'monument_nom': 'Tour Pey-Berland Ã\xa0 Bordeaux',
#   'Frequentation': '51685'},
#  {'monument_id': '68',
#   'monument_nom': "Tours de la cathÃ©drale d'Amiens",
#   'Frequentation': '8819'},
#  {'monument_id': '69',
#   'monument_nom': 'Tours de la cathÃ©drale de Chartres',
#   'Frequentation': '26055'},
#  {'monument_id': '70',
#   'monument_nom': 'Tours de la cathÃ©drale de Reims',
#   'Frequentation': '11439'},
#  {'monument_id': '71',
#   'monument_nom': 'Tours de la cathÃ©drale Notre-Dame de Paris',
#   'Frequentation': '494283'},
#  {'monument_id': '72',
#   'monument_nom': 'Tours de La Rochelle',
#   'Frequentation': '119033'},
#  {'monument_id': '73',
#   'monument_nom': "Tours et remparts d'Aigues-Mortes",
#   'Frequentation': '167051'},
#  {'monument_id': '74',
#   'monument_nom': "TrophÃ©e d'Auguste Ã\xa0 La Turbie",
#   'Frequentation': '18595'},
#  {'monument_id': '75',
#   'monument_nom': 'Villa Savoye Ã\xa0 Poissy',
#   'Frequentation': '32884'}]

# %%
table_coord=depuis_csv('monuments_GPS.csv')
table_coord
# Out:
# [{'monument_id': '1',
#   'monument_nom': 'Abbaye de Beaulieu-en-Rouergue',
#   'monument_lat': '44.2012986',
#   'monument_lon': '1.8576953'},
#  {'monument_id': '2',
#   'monument_nom': 'Abbaye de Charroux',
#   'monument_lat': '46.141736',
#   'monument_lon': '0.404965'},
#  {'monument_id': '3',
#   'monument_nom': 'Abbaye de Cluny',
#   'monument_lat': '46.43517292',
#   'monument_lon': '4.658219218'},
#  {'monument_id': '4',
#   'monument_nom': 'Abbaye de La Sauve-Majeure',
#   'monument_lat': '44.7679',
#   'monument_lon': '-0.3125'},
#  {'monument_id': '5',
#   'monument_nom': 'Abbaye de Montmajour',
#   'monument_lat': '43.70567881',
#   'monument_lon': '4.664148241'},
#  {'monument_id': '6',
#   'monument_nom': 'Abbaye du Bec-Hellouin',
#   'monument_lat': '49.228611',
#   'monument_lon': '0.721667'},
#  {'monument_id': '7',
#   'monument_nom': 'Abbaye du Mont-Saint-Michel',
#   'monument_lat': '48.63597158',
#   'monument_lon': '-1.511414051'},
#  {'monument_id': '8',
#   'monument_nom': 'Abbaye du Thoronet',
#   'monument_lat': '43.4501102',
#   'monument_lon': '6.3080895'},
#  {'monument_id': '9',
#   'monument_nom': 'Alignements de Carnac',
#   'monument_lat': '47.597702',
#   'monument_lon': '-3.0633934'},
#  {'monument_id': '10',
#   'monument_nom': 'Arc de triomphe',
#   'monument_lat': '48.873818',
#   'monument_lon': '2.295023'},
#  {'monument_id': '11',
#   'monument_nom': 'Basilique cathÃ©drale de Saint-Denis',
#   'monument_lat': '48.93541968',
#   'monument_lon': '2.35991478'},
#  {'monument_id': '12',
#   'monument_nom': 'Cairn de Barnenez',
#   'monument_lat': '48.66756914',
#   'monument_lon': '-3.858427405'},
#  {'monument_id': '13',
#   'monument_nom': 'CathÃ©drale de BesanÃ§on et son horloge astronomique',
#   'monument_lat': '47.2336343',
#   'monument_lon': '6.0303255'},
#  {'monument_id': '14',
#   'monument_nom': 'Chapelle expiatoire',
#   'monument_lat': '48.8736986',
#   'monument_lon': '2.322691083'},
#  {'monument_id': '15',
#   'monument_nom': "ChÃ¢teau d'Angers",
#   'monument_lat': '47.4698136',
#   'monument_lon': '-0.5593384'},
#  {'monument_id': '16',
#   'monument_nom': "ChÃ¢teau d'Assier",
#   'monument_lat': '44.6752839',
#   'monument_lon': '1.8792255'},
#  {'monument_id': '17',
#   'monument_nom': "ChÃ¢teau d'Aulteribe",
#   'monument_lat': '45.775',
#   'monument_lon': '3.498889'},
#  {'monument_id': '18',
#   'monument_nom': "ChÃ¢teau d'Azay-le-Rideau",
#   'monument_lat': '47.2595533',
#   'monument_lon': '0.4666037'},
#  {'monument_id': '19',
#   'monument_nom': "ChÃ¢teau d'If",
#   'monument_lat': '43.27985713',
#   'monument_lon': '5.325134397'},
#  {'monument_id': '20',
#   'monument_nom': "ChÃ¢teau d'Oiron",
#   'monument_lat': '46.95187347',
#   'monument_lon': '-0.07733345'},
#  {'monument_id': '21',
#   'monument_nom': 'ChÃ¢teau de Bouges',
#   'monument_lat': '47.04240481',
#   'monument_lon': '1.672968864'},
#  {'monument_id': '22',
#   'monument_nom': 'ChÃ¢teau de Bussy-Rabutin',
#   'monument_lat': '47.56157768',
#   'monument_lon': '4.523475766'},
#  {'monument_id': '23',
#   'monument_nom': 'ChÃ¢teau de Cadillac',
#   'monument_lat': '44.63810122',
#   'monument_lon': '-0.320652723'},
#  {'monument_id': '24',
#   'monument_nom': 'ChÃ¢teau de Carrouges',
#   'monument_lat': '48.56012908',
#   'monument_lon': '-0.154345036'},
#  {'monument_id': '25',
#   'monument_nom': 'ChÃ¢teau de Castelnau-Bretenoux',
#   'monument_lat': '44.8992',
#   'monument_lon': '1.8256'},
#  {'monument_id': '26',
#   'monument_nom': 'ChÃ¢teau de Chareil-Cintrat',
#   'monument_lat': '46.23942016',
#   'monument_lon': '3.229722977'},
#  {'monument_id': '27',
#   'monument_nom': 'ChÃ¢teau de ChÃ¢teaudun',
#   'monument_lat': '48.07079562',
#   'monument_lon': '1.323723793'},
#  {'monument_id': '28',
#   'monument_nom': 'ChÃ¢teau de Coucy',
#   'monument_lat': '49.52177486',
#   'monument_lon': '3.318611383'},
#  {'monument_id': '29',
#   'monument_nom': 'ChÃ¢teau de FougÃ¨res-sur-BiÃ¨vre',
#   'monument_lat': '47.44773885',
#   'monument_lon': '1.343808174'},
#  {'monument_id': '30',
#   'monument_nom': 'ChÃ¢teau de Gramont',
#   'monument_lat': '43.9580329',
#   'monument_lon': '0.9211763'},
#  {'monument_id': '31',
#   'monument_nom': 'ChÃ¢teau de La Motte-Tilly',
#   'monument_lat': '48.46713457',
#   'monument_lon': '3.431473374'},
#  {'monument_id': '32',
#   'monument_nom': 'ChÃ¢teau de Montal',
#   'monument_lat': '44.8624197',
#   'monument_lon': '1.8599192'},
#  {'monument_id': '33',
#   'monument_nom': 'ChÃ¢teau de Pierrefonds',
#   'monument_lat': '49.34699376',
#   'monument_lon': '2.980197072'},
#  {'monument_id': '34',
#   'monument_nom': 'ChÃ¢teau de Puyguilhem',
#   'monument_lat': '45.425833',
#   'monument_lon': '0.744444'},
#  {'monument_id': '35',
#   'monument_nom': 'ChÃ¢teau de Rambouillet et Laiterie de la Reine et ChaumiÃ¨re aux Coquillages',
#   'monument_lat': '48.64540401',
#   'monument_lon': '1.817328036'},
#  {'monument_id': '36',
#   'monument_nom': 'ChÃ¢teau de Talcy',
#   'monument_lat': '47.76975536',
#   'monument_lon': '1.444476843'},
#  {'monument_id': '37',
#   'monument_nom': 'ChÃ¢teau de Villeneuve-Lembron',
#   'monument_lat': '45.47799655',
#   'monument_lon': '3.185970783'},
#  {'monument_id': '38',
#   'monument_nom': 'ChÃ¢teau de Vincennes',
#   'monument_lat': '48.84266825',
#   'monument_lon': '2.435703278'},
#  {'monument_id': '39',
#   'monument_nom': 'ChÃ¢teau de Voltaire Ã\xa0 Ferney',
#   'monument_lat': '46.2581309',
#   'monument_lon': '6.1043544'},
#  {'monument_id': '40',
#   'monument_nom': 'ChÃ¢teau et remparts de la citÃ© de Carcassonne',
#   'monument_lat': '43.20728336',
#   'monument_lon': '2.363262177'},
#  {'monument_id': '41',
#   'monument_nom': 'CloÃ®tre de la cathÃ©drale de FrÃ©jus',
#   'monument_lat': '43.43306278',
#   'monument_lon': '6.737151146'},
#  {'monument_id': '42',
#   'monument_nom': 'CloÃ®tre de la cathÃ©drale du Puy-en-Velay',
#   'monument_lat': '45.0461801',
#   'monument_lon': '3.8848592'},
#  {'monument_id': '43',
#   'monument_nom': 'CloÃ®tre de la Psalette Ã\xa0 Tours',
#   'monument_lat': '47.39582912',
#   'monument_lon': '0.694069862'},
#  {'monument_id': '44',
#   'monument_nom': 'Colonne de la Grande ArmÃ©e Ã\xa0 Wimille',
#   'monument_lat': '50.7644118',
#   'monument_lon': '1.6310642'},
#  {'monument_id': '45',
#   'monument_nom': 'Conciergerie',
#   'monument_lat': '48.85581755',
#   'monument_lon': '2.3459512'},
#  {'monument_id': '46',
#   'monument_nom': 'Domaine national de Saint-Cloud',
#   'monument_lat': '48.83682143',
#   'monument_lon': '2.218208313'},
#  {'monument_id': '47',
#   'monument_nom': 'Fort Saint-AndrÃ© Ã\xa0 Villeneuve-lez-Avignon',
#   'monument_lat': '43.9662',
#   'monument_lon': '4.8001'},
#  {'monument_id': '48',
#   'monument_nom': 'Forteresse de Salses',
#   'monument_lat': '42.83968028',
#   'monument_lon': '2.918302417'},
#  {'monument_id': '49',
#   'monument_nom': 'Grotte de Pair-non-Pair',
#   'monument_lat': '45.0396354',
#   'monument_lon': '-0.5022214'},
#  {'monument_id': '50',
#   'monument_nom': "Maison d'Ernest Renan Ã\xa0 TrÃ©guier",
#   'monument_lat': '48.788491',
#   'monument_lon': '-3.2271867'},
#  {'monument_id': '51',
#   'monument_nom': 'Maison de George Sand Ã\xa0 Nohant',
#   'monument_lat': '46.6254445',
#   'monument_lon': '1.9749036'},
#  {'monument_id': '52',
#   'monument_nom': 'Maison de Georges Clemenceau Ã\xa0 Saint-Vincent-sur-Jard',
#   'monument_lat': '46.4063',
#   'monument_lon': '-1.5474'},
#  {'monument_id': '53',
#   'monument_nom': 'Maison des Jardies Ã\xa0 SÃ¨vres',
#   'monument_lat': '48.8272072',
#   'monument_lon': '2.1985906'},
#  {'monument_id': '54',
#   'monument_nom': 'MonastÃ¨re de Saorge',
#   'monument_lat': '43.9878757',
#   'monument_lon': '7.5509564'},
#  {'monument_id': '55',
#   'monument_nom': 'MonastÃ¨re royal de Brou Ã\xa0 Bourg-en-Bresse',
#   'monument_lat': '46.1978767',
#   'monument_lon': '5.2356066'},
#  {'monument_id': '56',
#   'monument_nom': 'Palais du Tau Ã\xa0 Reims',
#   'monument_lat': '49.25309012',
#   'monument_lon': '4.034181833'},
#  {'monument_id': '57',
#   'monument_nom': 'Palais Jacques Coeur Ã\xa0 Bourges',
#   'monument_lat': '47.085296',
#   'monument_lon': '2.3944818'},
#  {'monument_id': '58',
#   'monument_nom': 'PanthÃ©on',
#   'monument_lat': '48.84628421',
#   'monument_lon': '2.34607324'},
#  {'monument_id': '59',
#   'monument_nom': 'Place forte de Mont-Dauphin',
#   'monument_lat': '44.6691299',
#   'monument_lon': '6.6252286'},
#  {'monument_id': '60',
#   'monument_nom': 'Sainte-Chapelle',
#   'monument_lat': '48.85536753',
#   'monument_lon': '2.345023155'},
#  {'monument_id': '61',
#   'monument_nom': 'Site archÃ©ologique de Glanum',
#   'monument_lat': '43.7736',
#   'monument_lon': '4.833'},
#  {'monument_id': '62',
#   'monument_nom': 'Site archÃ©ologique de Montcaret',
#   'monument_lat': '44.8587327',
#   'monument_lon': '0.0638404'},
#  {'monument_id': '63',
#   'monument_nom': "Site archÃ©ologique et musÃ©e d'EnsÃ©rune",
#   'monument_lat': '43.310556',
#   'monument_lon': '3.115278'},
#  {'monument_id': '64',
#   'monument_nom': 'Site des mÃ©galithes de Locmariaquer',
#   'monument_lat': '47.5732972',
#   'monument_lon': '-2.9574633'},
#  {'monument_id': '65',
#   'monument_nom': 'Site gallo-romain de Sanxay',
#   'monument_lat': '46.4941324',
#   'monument_lon': '-0.0070385'},
#  {'monument_id': '66',
#   'monument_nom': 'Tour et crypte de la cathÃ©drale de Bourges',
#   'monument_lat': '47.08241152',
#   'monument_lon': '2.398495674'},
#  {'monument_id': '67',
#   'monument_nom': 'Tour Pey-Berland Ã\xa0 Bordeaux',
#   'monument_lat': '44.8379962',
#   'monument_lon': '-0.5777064'},
#  {'monument_id': '68',
#   'monument_nom': "Tours de la cathÃ©drale d'Amiens",
#   'monument_lat': '49.895',
#   'monument_lon': '2.302222'},
#  {'monument_id': '69',
#   'monument_nom': 'Tours de la cathÃ©drale de Chartres',
#   'monument_lat': '48.44776369',
#   'monument_lon': '1.487982273'},
#  {'monument_id': '70',
#   'monument_nom': 'Tours de la cathÃ©drale de Reims',
#   'monument_lat': '49.2534',
#   'monument_lon': '4.033'},
#  {'monument_id': '71',
#   'monument_nom': 'Tours de la cathÃ©drale Notre-Dame de Paris',
#   'monument_lat': '48.85297618',
#   'monument_lon': '2.349953055'},
#  {'monument_id': '72',
#   'monument_nom': 'Tours de La Rochelle',
#   'monument_lat': '46.15580101',
#   'monument_lon': '-1.153231859'},
#  {'monument_id': '73',
#   'monument_nom': "Tours et remparts d'Aigues-Mortes",
#   'monument_lat': '43.56781436',
#   'monument_lon': '4.190865755'},
#  {'monument_id': '74',
#   'monument_nom': "TrophÃ©e d'Auguste Ã\xa0 La Turbie",
#   'monument_lat': '43.74480501',
#   'monument_lon': '7.401840091'},
#  {'monument_id': '75',
#   'monument_nom': 'Villa Savoye Ã\xa0 Poissy',
#   'monument_lat': '48.92442556',
#   'monument_lon': '2.028270364'}]

# %%
table_fusion=union(table_freq, table_coord,'monument_nom')
table_fusion
# Out:
# [{'monument_id': '1',
#   'monument_nom': 'Abbaye de Beaulieu-en-Rouergue',
#   'Frequentation': '8819',
#   'monument_lat': '44.2012986',
#   'monument_lon': '1.8576953'},
#  {'monument_id': '2',
#   'monument_nom': 'Abbaye de Charroux',
#   'Frequentation': '1883',
#   'monument_lat': '46.141736',
#   'monument_lon': '0.404965'},
#  {'monument_id': '3',
#   'monument_nom': 'Abbaye de Cluny',
#   'Frequentation': '124110',
#   'monument_lat': '46.43517292',
#   'monument_lon': '4.658219218'},
#  {'monument_id': '4',
#   'monument_nom': 'Abbaye de La Sauve-Majeure',
#   'Frequentation': '13390',
#   'monument_lat': '44.7679',
#   'monument_lon': '-0.3125'},
#  {'monument_id': '5',
#   'monument_nom': 'Abbaye de Montmajour',
#   'Frequentation': '40234',
#   'monument_lat': '43.70567881',
#   'monument_lon': '4.664148241'},
#  {'monument_id': '6',
#   'monument_nom': 'Abbaye du Bec-Hellouin',
#   'Frequentation': '7243',
#   'monument_lat': '49.228611',
#   'monument_lon': '0.721667'},
#  {'monument_id': '7',
#   'monument_nom': 'Abbaye du Mont-Saint-Michel',
#   'Frequentation': '1270506',
#   'monument_lat': '48.63597158',
#   'monument_lon': '-1.511414051'},
#  {'monument_id': '8',
#   'monument_nom': 'Abbaye du Thoronet',
#   'Frequentation': '107935',
#   'monument_lat': '43.4501102',
#   'monument_lon': '6.3080895'},
#  {'monument_id': '9',
#   'monument_nom': 'Alignements de Carnac',
#   'Frequentation': '23567',
#   'monument_lat': '47.597702',
#   'monument_lon': '-3.0633934'},
#  {'monument_id': '10',
#   'monument_nom': 'Arc de triomphe',
#   'Frequentation': '1732280',
#   'monument_lat': '48.873818',
#   'monument_lon': '2.295023'},
#  {'monument_id': '11',
#   'monument_nom': 'Basilique cathÃ©drale de Saint-Denis',
#   'Frequentation': '171441',
#   'monument_lat': '48.93541968',
#   'monument_lon': '2.35991478'},
#  {'monument_id': '12',
#   'monument_nom': 'Cairn de Barnenez',
#   'Frequentation': '32499',
#   'monument_lat': '48.66756914',
#   'monument_lon': '-3.858427405'},
#  {'monument_id': '13',
#   'monument_nom': 'CathÃ©drale de BesanÃ§on et son horloge astronomique',
#   'Frequentation': '7445',
#   'monument_lat': '47.2336343',
#   'monument_lon': '6.0303255'},
#  {'monument_id': '14',
#   'monument_nom': 'Chapelle expiatoire',
#   'Frequentation': '6021',
#   'monument_lat': '48.8736986',
#   'monument_lon': '2.322691083'},
#  {'monument_id': '15',
#   'monument_nom': "ChÃ¢teau d'Angers",
#   'Frequentation': '166533',
#   'monument_lat': '47.4698136',
#   'monument_lon': '-0.5593384'},
#  {'monument_id': '16',
#   'monument_nom': "ChÃ¢teau d'Assier",
#   'Frequentation': '3948',
#   'monument_lat': '44.6752839',
#   'monument_lon': '1.8792255'},
#  {'monument_id': '17',
#   'monument_nom': "ChÃ¢teau d'Aulteribe",
#   'Frequentation': '6693',
#   'monument_lat': '45.775',
#   'monument_lon': '3.498889'},
#  {'monument_id': '18',
#   'monument_nom': "ChÃ¢teau d'Azay-le-Rideau",
#   'Frequentation': '293594',
#   'monument_lat': '47.2595533',
#   'monument_lon': '0.4666037'},
#  {'monument_id': '19',
#   'monument_nom': "ChÃ¢teau d'If",
#   'Frequentation': '90584',
#   'monument_lat': '43.27985713',
#   'monument_lon': '5.325134397'},
#  {'monument_id': '20',
#   'monument_nom': "ChÃ¢teau d'Oiron",
#   'Frequentation': '20035',
#   'monument_lat': '46.95187347',
#   'monument_lon': '-0.07733345'},
#  {'monument_id': '21',
#   'monument_nom': 'ChÃ¢teau de Bouges',
#   'Frequentation': '11608',
#   'monument_lat': '47.04240481',
#   'monument_lon': '1.672968864'},
#  {'monument_id': '22',
#   'monument_nom': 'ChÃ¢teau de Bussy-Rabutin',
#   'Frequentation': '31940',
#   'monument_lat': '47.56157768',
#   'monument_lon': '4.523475766'},
#  {'monument_id': '23',
#   'monument_nom': 'ChÃ¢teau de Cadillac',
#   'Frequentation': '11071',
#   'monument_lat': '44.63810122',
#   'monument_lon': '-0.320652723'},
#  {'monument_id': '24',
#   'monument_nom': 'ChÃ¢teau de Carrouges',
#   'Frequentation': '22907',
#   'monument_lat': '48.56012908',
#   'monument_lon': '-0.154345036'},
#  {'monument_id': '25',
#   'monument_nom': 'ChÃ¢teau de Castelnau-Bretenoux',
#   'Frequentation': '47494',
#   'monument_lat': '44.8992',
#   'monument_lon': '1.8256'},
#  {'monument_id': '26',
#   'monument_nom': 'ChÃ¢teau de Chareil-Cintrat',
#   'Frequentation': '2018',
#   'monument_lat': '46.23942016',
#   'monument_lon': '3.229722977'},
#  {'monument_id': '27',
#   'monument_nom': 'ChÃ¢teau de ChÃ¢teaudun',
#   'Frequentation': '20615',
#   'monument_lat': '48.07079562',
#   'monument_lon': '1.323723793'},
#  {'monument_id': '28',
#   'monument_nom': 'ChÃ¢teau de Coucy',
#   'Frequentation': '14528',
#   'monument_lat': '49.52177486',
#   'monument_lon': '3.318611383'},
#  {'monument_id': '29',
#   'monument_nom': 'ChÃ¢teau de FougÃ¨res-sur-BiÃ¨vre',
#   'Frequentation': '17227',
#   'monument_lat': '47.44773885',
#   'monument_lon': '1.343808174'},
#  {'monument_id': '30',
#   'monument_nom': 'ChÃ¢teau de Gramont',
#   'Frequentation': '4681',
#   'monument_lat': '43.9580329',
#   'monument_lon': '0.9211763'},
#  {'monument_id': '31',
#   'monument_nom': 'ChÃ¢teau de La Motte-Tilly',
#   'Frequentation': '4111',
#   'monument_lat': '48.46713457',
#   'monument_lon': '3.431473374'},
#  {'monument_id': '32',
#   'monument_nom': 'ChÃ¢teau de Montal',
#   'Frequentation': '17713',
#   'monument_lat': '44.8624197',
#   'monument_lon': '1.8599192'},
#  {'monument_id': '33',
#   'monument_nom': 'ChÃ¢teau de Pierrefonds',
#   'Frequentation': '134568',
#   'monument_lat': '49.34699376',
#   'monument_lon': '2.980197072'},
#  {'monument_id': '34',
#   'monument_nom': 'ChÃ¢teau de Puyguilhem',
#   'Frequentation': '15361',
#   'monument_lat': '45.425833',
#   'monument_lon': '0.744444'},
#  {'monument_id': '35',
#   'monument_nom': 'ChÃ¢teau de Rambouillet et Laiterie de la Reine et ChaumiÃ¨re aux Coquillages',
#   'Frequentation': '28418',
#   'monument_lat': '48.64540401',
#   'monument_lon': '1.817328036'},
#  {'monument_id': '36',
#   'monument_nom': 'ChÃ¢teau de Talcy',
#   'Frequentation': '13453',
#   'monument_lat': '47.76975536',
#   'monument_lon': '1.444476843'},
#  {'monument_id': '37',
#   'monument_nom': 'ChÃ¢teau de Villeneuve-Lembron',
#   'Frequentation': '6975',
#   'monument_lat': '45.47799655',
#   'monument_lon': '3.185970783'},
#  {'monument_id': '38',
#   'monument_nom': 'ChÃ¢teau de Vincennes',
#   'Frequentation': '139155',
#   'monument_lat': '48.84266825',
#   'monument_lon': '2.435703278'},
#  {'monument_id': '39',
#   'monument_nom': 'ChÃ¢teau de Voltaire Ã\xa0 Ferney',
#   'Frequentation': '10536',
#   'monument_lat': '46.2581309',
#   'monument_lon': '6.1043544'},
#  {'monument_id': '40',
#   'monument_nom': 'ChÃ¢teau et remparts de la citÃ© de Carcassonne',
#   'Frequentation': '471707',
#   'monument_lat': '43.20728336',
#   'monument_lon': '2.363262177'},
#  {'monument_id': '41',
#   'monument_nom': 'CloÃ®tre de la cathÃ©drale de FrÃ©jus',
#   'Frequentation': '25865',
#   'monument_lat': '43.43306278',
#   'monument_lon': '6.737151146'},
#  {'monument_id': '42',
#   'monument_nom': 'CloÃ®tre de la cathÃ©drale du Puy-en-Velay',
#   'Frequentation': '24783',
#   'monument_lat': '45.0461801',
#   'monument_lon': '3.8848592'},
#  {'monument_id': '43',
#   'monument_nom': 'CloÃ®tre de la Psalette Ã\xa0 Tours',
#   'Frequentation': '17804',
#   'monument_lat': '47.39582912',
#   'monument_lon': '0.694069862'},
#  {'monument_id': '44',
#   'monument_nom': 'Colonne de la Grande ArmÃ©e Ã\xa0 Wimille',
#   'Frequentation': '4881',
#   'monument_lat': '50.7644118',
#   'monument_lon': '1.6310642'},
#  {'monument_id': '45',
#   'monument_nom': 'Conciergerie',
#   'Frequentation': '456589',
#   'monument_lat': '48.85581755',
#   'monument_lon': '2.3459512'},
#  {'monument_id': '46',
#   'monument_nom': 'Domaine national de Saint-Cloud',
#   'Frequentation': '141019',
#   'monument_lat': '48.83682143',
#   'monument_lon': '2.218208313'},
#  {'monument_id': '47',
#   'monument_nom': 'Fort Saint-AndrÃ© Ã\xa0 Villeneuve-lez-Avignon',
#   'Frequentation': '29068',
#   'monument_lat': '43.9662',
#   'monument_lon': '4.8001'},
#  {'monument_id': '48',
#   'monument_nom': 'Forteresse de Salses',
#   'Frequentation': '77951',
#   'monument_lat': '42.83968028',
#   'monument_lon': '2.918302417'},
#  {'monument_id': '49',
#   'monument_nom': 'Grotte de Pair-non-Pair',
#   'Frequentation': '11316',
#   'monument_lat': '45.0396354',
#   'monument_lon': '-0.5022214'},
#  {'monument_id': '50',
#   'monument_nom': "Maison d'Ernest Renan Ã\xa0 TrÃ©guier",
#   'Frequentation': '33077',
#   'monument_lat': '48.788491',
#   'monument_lon': '-3.2271867'},
#  {'monument_id': '51',
#   'monument_nom': 'Maison de George Sand Ã\xa0 Nohant',
#   'Frequentation': '16639',
#   'monument_lat': '46.6254445',
#   'monument_lon': '1.9749036'},
#  {'monument_id': '52',
#   'monument_nom': 'Maison de Georges Clemenceau Ã\xa0 Saint-Vincent-sur-Jard',
#   'Frequentation': '2743',
#   'monument_lat': '46.4063',
#   'monument_lon': '-1.5474'},
#  {'monument_id': '53',
#   'monument_nom': 'Maison des Jardies Ã\xa0 SÃ¨vres',
#   'Frequentation': '867',
#   'monument_lat': '48.8272072',
#   'monument_lon': '2.1985906'},
#  {'monument_id': '54',
#   'monument_nom': 'MonastÃ¨re de Saorge',
#   'Frequentation': '7374',
#   'monument_lat': '43.9878757',
#   'monument_lon': '7.5509564'},
#  {'monument_id': '55',
#   'monument_nom': 'MonastÃ¨re royal de Brou Ã\xa0 Bourg-en-Bresse',
#   'Frequentation': '57627',
#   'monument_lat': '46.1978767',
#   'monument_lon': '5.2356066'},
#  {'monument_id': '56',
#   'monument_nom': 'Palais du Tau Ã\xa0 Reims',
#   'Frequentation': '62623',
#   'monument_lat': '49.25309012',
#   'monument_lon': '4.034181833'},
#  {'monument_id': '57',
#   'monument_nom': 'Palais Jacques Coeur Ã\xa0 Bourges',
#   'Frequentation': '47464',
#   'monument_lat': '47.085296',
#   'monument_lon': '2.3944818'},
#  {'monument_id': '58',
#   'monument_nom': 'PanthÃ©on',
#   'Frequentation': '724392',
#   'monument_lat': '48.84628421',
#   'monument_lon': '2.34607324'},
#  {'monument_id': '59',
#   'monument_nom': 'Place forte de Mont-Dauphin',
#   'Frequentation': '10652',
#   'monument_lat': '44.6691299',
#   'monument_lon': '6.6252286'},
#  {'monument_id': '60',
#   'monument_nom': 'Sainte-Chapelle',
#   'Frequentation': '951807',
#   'monument_lat': '48.85536753',
#   'monument_lon': '2.345023155'},
#  {'monument_id': '61',
#   'monument_nom': 'Site archÃ©ologique de Glanum',
#   'Frequentation': '73795',
#   'monument_lat': '43.7736',
#   'monument_lon': '4.833'},
#  {'monument_id': '62',
#   'monument_nom': 'Site archÃ©ologique de Montcaret',
#   'Frequentation': '7651',
#   'monument_lat': '44.8587327',
#   'monument_lon': '0.0638404'},
#  {'monument_id': '63',
#   'monument_nom': "Site archÃ©ologique et musÃ©e d'EnsÃ©rune",
#   'Frequentation': '30095',
#   'monument_lat': '43.310556',
#   'monument_lon': '3.115278'},
#  {'monument_id': '64',
#   'monument_nom': 'Site des mÃ©galithes de Locmariaquer',
#   'Frequentation': '56656',
#   'monument_lat': '47.5732972',
#   'monument_lon': '-2.9574633'},
#  {'monument_id': '65',
#   'monument_nom': 'Site gallo-romain de Sanxay',
#   'Frequentation': '6243',
#   'monument_lat': '46.4941324',
#   'monument_lon': '-0.0070385'},
#  {'monument_id': '66',
#   'monument_nom': 'Tour et crypte de la cathÃ©drale de Bourges',
#   'Frequentation': '33506',
#   'monument_lat': '47.08241152',
#   'monument_lon': '2.398495674'},
#  {'monument_id': '67',
#   'monument_nom': 'Tour Pey-Berland Ã\xa0 Bordeaux',
#   'Frequentation': '51685',
#   'monument_lat': '44.8379962',
#   'monument_lon': '-0.5777064'},
#  {'monument_id': '68',
#   'monument_nom': "Tours de la cathÃ©drale d'Amiens",
#   'Frequentation': '8819',
#   'monument_lat': '49.895',
#   'monument_lon': '2.302222'},
#  {'monument_id': '69',
#   'monument_nom': 'Tours de la cathÃ©drale de Chartres',
#   'Frequentation': '26055',
#   'monument_lat': '48.44776369',
#   'monument_lon': '1.487982273'},
#  {'monument_id': '70',
#   'monument_nom': 'Tours de la cathÃ©drale de Reims',
#   'Frequentation': '11439',
#   'monument_lat': '49.2534',
#   'monument_lon': '4.033'},
#  {'monument_id': '71',
#   'monument_nom': 'Tours de la cathÃ©drale Notre-Dame de Paris',
#   'Frequentation': '494283',
#   'monument_lat': '48.85297618',
#   'monument_lon': '2.349953055'},
#  {'monument_id': '72',
#   'monument_nom': 'Tours de La Rochelle',
#   'Frequentation': '119033',
#   'monument_lat': '46.15580101',
#   'monument_lon': '-1.153231859'},
#  {'monument_id': '73',
#   'monument_nom': "Tours et remparts d'Aigues-Mortes",
#   'Frequentation': '167051',
#   'monument_lat': '43.56781436',
#   'monument_lon': '4.190865755'},
#  {'monument_id': '74',
#   'monument_nom': "TrophÃ©e d'Auguste Ã\xa0 La Turbie",
#   'Frequentation': '18595',
#   'monument_lat': '43.74480501',
#   'monument_lon': '7.401840091'},
#  {'monument_id': '75',
#   'monument_nom': 'Villa Savoye Ã\xa0 Poissy',
#   'Frequentation': '32884',
#   'monument_lat': '48.92442556',
#   'monument_lon': '2.028270364'}]

# %% [markdown]
# ### 7) Longueur d'une table

# %% [markdown]
# longueur est une instruction permettant de connaitre le nombre d'enregistrements (ou lignes) dans une table.

# %%
def longueur(table: Table)->int:
    return len(table)

# %%
longueur(dico)
# Out:
# 75

# %% [markdown]
# <h2>Utilisation de Folium </h2>

# %% [markdown]
# Création de la carte

# %%
#bibliothèque folium à télécharger via la commande pip install folium ou conda install folium

import folium
#Création de la carte centrée aux coordonnées Latitude = 48 et Longitude = 2 
carte= folium.Map(location=[48, 2],zoom_start=6)
carte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Placement des marqueurs aux coordonnées de chaque monuments se trouvant dans la table

# %%
for i in range (0, len(dico)):
    """ 
   convertir en float les coordonées 
   popup affiche le nom du monument 
   
   """
    folium.Marker([float(dico[i]['monument_lat']), float(dico[i]['monument_lon'])],popup=dico[i]['monument_nom']).add_to(carte)
carte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
